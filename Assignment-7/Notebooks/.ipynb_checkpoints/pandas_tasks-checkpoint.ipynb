# %%
# !pip install pandas

# %%
import pandas as pd

# %%
# Task 3:
data = {
    'Name': ['Ali', 'Aruzhan', 'Dias', 'Amina', 'Nursultan'],
    'Age': [19, 21, 22, 20, 23],
    'Score': [85, 90, 78, 88, 92]
}

df = pd.DataFrame(data)
df
# Out:
#         Name  Age  Score
# 0        Ali   19     85
# 1    Aruzhan   21     90
# 2       Dias   22     78
# 3      Amina   20     88
# 4  Nursultan   23     92

# %%
# Task 4:

df.head(3)

df.describe()

df['Score'].mean()
# Out:
# np.float64(86.6)

# %%
# Task 5:


df[df['Age'] > 20]

df[df['Score'] > 80]
# Out:
#         Name  Age  Score
# 0        Ali   19     85
# 1    Aruzhan   21     90
# 3      Amina   20     88
# 4  Nursultan   23     92
